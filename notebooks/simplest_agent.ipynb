# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[19], line 21
#       9     print(
#      10         """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
#      11
#    (...)     15     """
#      16     )
#      18 # Test OpenAI Access
#      19 print(
#      20     OpenAI()
# ---> 21     .responses.create(
#      22         model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
#      23     )
#      24     .output_text
#      25 )
#
# File ~/.local/lib/python3.13/site-packages/openai/resources/responses/responses.py:828, in Responses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     791 def create(
#     792     self,
#     793     *,
#    (...)    826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> Response | Stream[ResponseStreamEvent]:
# --> 828     return self._post(
#     829         "/responses",
#     830         body=maybe_transform(
#     831             {
#     832                 "background": background,
#     833                 "conversation": conversation,
#     834                 "include": include,
#     835                 "input": input,
#     836                 "instructions": instructions,
#     837                 "max_output_tokens": max_output_tokens,
#     838                 "max_tool_calls": max_tool_calls,
#     839                 "metadata": metadata,
#     840                 "model": model,
#     841                 "parallel_tool_calls": parallel_tool_calls,
#     842                 "previous_response_id": previous_response_id,
#     843                 "prompt": prompt,
#     844                 "prompt_cache_key": prompt_cache_key,
#     845                 "reasoning": reasoning,
#     846                 "safety_identifier": safety_identifier,
#     847                 "service_tier": service_tier,
#     848                 "store": store,
#     849                 "stream": stream,
#     850                 "stream_options": stream_options,
#     851                 "temperature": temperature,
#     852                 "text": text,
#     853                 "tool_choice": tool_choice,
#     854                 "tools": tools,
#     855                 "top_logprobs": top_logprobs,
#     856                 "top_p": top_p,
#     857                 "truncation": truncation,
#     858                 "user": user,
#     859             },
#     860             response_create_params.ResponseCreateParamsStreaming
#     861             if stream
#     862             else response_create_params.ResponseCreateParamsNonStreaming,
#     863         ),
#     864         options=make_request_options(
#     865             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     866         ),
#     867         cast_to=Response,
#     868         stream=stream or False,
#     869         stream_cls=Stream[ResponseStreamEvent],
#     870     )
#
# File ~/.local/lib/python3.13/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.13/site-packages/openai/_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: "sk-proj*********************************************************************************************************************************************************1kQA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions=""""
    You are a helpful assistant that provides nutritional information about food items.
    You give concise answers
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# Error getting response: Error code: 401 - {'error': {'message': 'Incorrect API key provided: "sk-proj*********************************************************************************************************************************************************1kQA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}. (request_id: req_6df37905df654d9585903a0c8e02d086)
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 with trace("Simple Nutrition Agent"):
# ----> 2     result = await Runner.run(nutrition_agent, "How healthy are bananas?")
#       4 print(result)
#
# File ~/.local/lib/python3.13/site-packages/agents/run.py:274, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     240 """Run a workflow starting at the given agent. The agent will run in a loop until a final
#     241 output is generated. The loop runs like so:
#     242 1. The agent is invoked with the given input.
#    (...)    271     agent. Agents may perform handoffs, so we don't know the specific type of the output.
#     272 """
#     273 runner = DEFAULT_AGENT_RUNNER
# --> 274 return await runner.run(
#     275     starting_agent,
#     276     input,
#     277     context=context,
#     278     max_turns=max_turns,
#     279     hooks=hooks,
#     280     run_config=run_config,
#     281     previous_response_id=previous_response_id,
#     282     conversation_id=conversation_id,
#     283     session=session,
#     284 )
#
# File ~/.local/lib/python3.13/site-packages/agents/run.py:494, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     489 logger.debug(
#     490     f"Running agent {current_agent.name} (turn {current_turn})",
#     491 )
#     493 if current_turn == 1:
# --> 494     input_guardrail_results, turn_result = await asyncio.gather(
#     495         self._run_input_guardrails(
#     496             starting_agent,
#     497             starting_agent.input_guardrails
#     498             + (run_config.input_guardrails or []),
#     499             _copy_str_or_list(prepared_input),
#     500             context_wrapper,
#     501         ),
#     502         self._run_single_turn(
#     503             agent=current_agent,
#     504             all_tools=all_tools,
#     505             original_input=original_input,
#     506             generated_items=generated_items,
#     507             hooks=hooks,
#     508             context_wrapper=context_wrapper,
#     509             run_config=run_config,
#     510             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     511             tool_use_tracker=tool_use_tracker,
#     512             previous_response_id=previous_response_id,
#     513             conversation_id=conversation_id,
#     514         ),
#     515     )
#     516 else:
#     517     turn_result = await self._run_single_turn(
#     518         agent=current_agent,
#     519         all_tools=all_tools,
#    (...)    528         conversation_id=conversation_id,
#     529     )
#
# File ~/.local/lib/python3.13/site-packages/agents/run.py:1165, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id, conversation_id)
#    1162 input = ItemHelpers.input_to_new_input_list(original_input)
#    1163 input.extend([generated_item.to_input_item() for generated_item in generated_items])
# -> 1165 new_response = await cls._get_new_response(
#    1166     agent,
#    1167     system_prompt,
#    1168     input,
#    1169     output_schema,
#    1170     all_tools,
#    1171     handoffs,
#    1172     hooks,
#    1173     context_wrapper,
#    1174     run_config,
#    1175     tool_use_tracker,
#    1176     previous_response_id,
#    1177     conversation_id,
#    1178     prompt_config,
#    1179 )
#    1181 return await cls._get_single_step_result_from_response(
#    1182     agent=agent,
#    1183     original_input=original_input,
#    (...)   1192     tool_use_tracker=tool_use_tracker,
#    1193 )
#
# File ~/.local/lib/python3.13/site-packages/agents/run.py:1404, in AgentRunner._get_new_response(cls, agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, previous_response_id, conversation_id, prompt_config)
#    1389 # If we have run hooks, or if the agent has hooks, we need to call them before the LLM call
#    1390 await asyncio.gather(
#    1391     hooks.on_llm_start(context_wrapper, agent, filtered.instructions, filtered.input),
#    1392     (
#    (...)   1401     ),
#    1402 )
# -> 1404 new_response = await model.get_response(
#    1405     system_instructions=filtered.instructions,
#    1406     input=filtered.input,
#    1407     model_settings=model_settings,
#    1408     tools=all_tools,
#    1409     output_schema=output_schema,
#    1410     handoffs=handoffs,
#    1411     tracing=get_model_tracing_impl(
#    1412         run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1413     ),
#    1414     previous_response_id=previous_response_id,
#    1415     conversation_id=conversation_id,
#    1416     prompt=prompt_config,
#    1417 )
#    1419 context_wrapper.usage.add(new_response.usage)
#    1421 # If we have run hooks, or if the agent has hooks, we need to call them after the LLM call
#
# File ~/.local/lib/python3.13/site-packages/agents/models/openai_responses.py:84, in OpenAIResponsesModel.get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#      82 with response_span(disabled=tracing.is_disabled()) as span_response:
#      83     try:
# ---> 84         response = await self._fetch_response(
#      85             system_instructions,
#      86             input,
#      87             model_settings,
#      88             tools,
#      89             output_schema,
#      90             handoffs,
#      91             previous_response_id=previous_response_id,
#      92             conversation_id=conversation_id,
#      93             stream=False,
#      94             prompt=prompt,
#      95         )
#      97         if _debug.DONT_LOG_MODEL_DATA:
#      98             logger.debug("LLM responded")
#
# File ~/.local/lib/python3.13/site-packages/agents/models/openai_responses.py:299, in OpenAIResponsesModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, previous_response_id, conversation_id, stream, prompt)
#     296     else:
#     297         response_format = {"verbosity": model_settings.verbosity}
# --> 299 return await self._client.responses.create(
#     300     previous_response_id=self._non_null_or_not_given(previous_response_id),
#     301     conversation=self._non_null_or_not_given(conversation_id),
#     302     instructions=self._non_null_or_not_given(system_instructions),
#     303     model=self.model,
#     304     input=list_input,
#     305     include=include,
#     306     tools=converted_tools_payload,
#     307     prompt=self._non_null_or_not_given(prompt),
#     308     temperature=self._non_null_or_not_given(model_settings.temperature),
#     309     top_p=self._non_null_or_not_given(model_settings.top_p),
#     310     truncation=self._non_null_or_not_given(model_settings.truncation),
#     311     max_output_tokens=self._non_null_or_not_given(model_settings.max_tokens),
#     312     tool_choice=tool_choice,
#     313     parallel_tool_calls=parallel_tool_calls,
#     314     stream=stream,
#     315     extra_headers={**_HEADERS, **(model_settings.extra_headers or {})},
#     316     extra_query=model_settings.extra_query,
#     317     extra_body=model_settings.extra_body,
#     318     text=response_format,
#     319     store=self._non_null_or_not_given(model_settings.store),
#     320     reasoning=self._non_null_or_not_given(model_settings.reasoning),
#     321     metadata=self._non_null_or_not_given(model_settings.metadata),
#     322     **extra_args,
#     323 )
#
# File ~/.local/lib/python3.13/site-packages/openai/resources/responses/responses.py:2259, in AsyncResponses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    2222 async def create(
#    2223     self,
#    2224     *,
#    (...)   2257     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    2258 ) -> Response | AsyncStream[ResponseStreamEvent]:
# -> 2259     return await self._post(
#    2260         "/responses",
#    2261         body=await async_maybe_transform(
#    2262             {
#    2263                 "background": background,
#    2264                 "conversation": conversation,
#    2265                 "include": include,
#    2266                 "input": input,
#    2267                 "instructions": instructions,
#    2268                 "max_output_tokens": max_output_tokens,
#    2269                 "max_tool_calls": max_tool_calls,
#    2270                 "metadata": metadata,
#    2271                 "model": model,
#    2272                 "parallel_tool_calls": parallel_tool_calls,
#    2273                 "previous_response_id": previous_response_id,
#    2274                 "prompt": prompt,
#    2275                 "prompt_cache_key": prompt_cache_key,
#    2276                 "reasoning": reasoning,
#    2277                 "safety_identifier": safety_identifier,
#    2278                 "service_tier": service_tier,
#    2279                 "store": store,
#    2280                 "stream": stream,
#    2281                 "stream_options": stream_options,
#    2282                 "temperature": temperature,
#    2283                 "text": text,
#    2284                 "tool_choice": tool_choice,
#    2285                 "tools": tools,
#    2286                 "top_logprobs": top_logprobs,
#    2287                 "top_p": top_p,
#    2288                 "truncation": truncation,
#    2289                 "user": user,
#    2290             },
#    2291             response_create_params.ResponseCreateParamsStreaming
#    2292             if stream
#    2293             else response_create_params.ResponseCreateParamsNonStreaming,
#    2294         ),
#    2295         options=make_request_options(
#    2296             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2297         ),
#    2298         cast_to=Response,
#    2299         stream=stream or False,
#    2300         stream_cls=AsyncStream[ResponseStreamEvent],
#    2301     )
#
# File ~/.local/lib/python3.13/site-packages/openai/_base_client.py:1794, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1780 async def post(
#    1781     self,
#    1782     path: str,
#    (...)   1789     stream_cls: type[_AsyncStreamT] | None = None,
#    1790 ) -> ResponseT | _AsyncStreamT:
#    1791     opts = FinalRequestOptions.construct(
#    1792         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1793     )
# -> 1794     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.local/lib/python3.13/site-packages/openai/_base_client.py:1594, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1591             await err.response.aread()
#    1593         log.debug("Re-raising status error")
# -> 1594         raise self._make_status_error_from_response(err.response) from None
#    1596     break
#    1598 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: "sk-proj*********************************************************************************************************************************************************1kQA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Error streaming response: Error code: 401 - {'error': {'message': 'Incorrect API key provided: "sk-proj*********************************************************************************************************************************************************1kQA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[18], line 3
#       1 response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")
# ----> 3 async for event in response_stream.stream_events():
#       4     if event.type == "raw_response_event" and isinstance(
#       5         event.data, ResponseTextDeltaEvent
#       6     ):
#       7         print(event.data.delta, end="", flush=True)
#
# File ~/.local/lib/python3.13/site-packages/agents/result.py:215, in RunResultStreaming.stream_events(self)
#     212 self._cleanup_tasks()
#     214 if self._stored_exception:
# --> 215     raise self._stored_exception
#
# File ~/.local/lib/python3.13/site-packages/agents/run.py:855, in AgentRunner._start_streaming(cls, starting_input, streamed_result, starting_agent, max_turns, hooks, context_wrapper, run_config, previous_response_id, conversation_id, session)
#     844     streamed_result._input_guardrails_task = asyncio.create_task(
#     845         cls._run_input_guardrails_with_queue(
#     846             starting_agent,
#    (...)    852         )
#     853     )
#     854 try:
# --> 855     turn_result = await cls._run_single_turn_streamed(
#     856         streamed_result,
#     857         current_agent,
#     858         hooks,
#     859         context_wrapper,
#     860         run_config,
#     861         should_run_agent_start_hooks,
#     862         tool_use_tracker,
#     863         all_tools,
#     864         previous_response_id,
#     865         conversation_id,
#     866     )
#     867     should_run_agent_start_hooks = False
#     869     streamed_result.raw_responses = streamed_result.raw_responses + [
#     870         turn_result.model_response
#     871     ]
#
# File ~/.local/lib/python3.13/site-packages/agents/run.py:1015, in AgentRunner._run_single_turn_streamed(cls, streamed_result, agent, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, all_tools, previous_response_id, conversation_id)
#    1003 await asyncio.gather(
#    1004     hooks.on_llm_start(context_wrapper, agent, filtered.instructions, filtered.input),
#    1005     (
#    (...)   1011     ),
#    1012 )
#    1014 # 1. Stream the output events
# -> 1015 async for event in model.stream_response(
#    1016     filtered.instructions,
#    1017     filtered.input,
#    1018     model_settings,
#    1019     all_tools,
#    1020     output_schema,
#    1021     handoffs,
#    1022     get_model_tracing_impl(
#    1023         run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1024     ),
#    1025     previous_response_id=previous_response_id,
#    1026     conversation_id=conversation_id,
#    1027     prompt=prompt_config,
#    1028 ):
#    1029     if isinstance(event, ResponseCompletedEvent):
#    1030         usage = (
#    1031             Usage(
#    1032                 requests=1,
#    (...)   1040             else Usage()
#    1041         )
#
# File ~/.local/lib/python3.13/site-packages/agents/models/openai_responses.py:164, in OpenAIResponsesModel.stream_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#     162 with response_span(disabled=tracing.is_disabled()) as span_response:
#     163     try:
# --> 164         stream = await self._fetch_response(
#     165             system_instructions,
#     166             input,
#     167             model_settings,
#     168             tools,
#     169             output_schema,
#     170             handoffs,
#     171             previous_response_id=previous_response_id,
#     172             conversation_id=conversation_id,
#     173             stream=True,
#     174             prompt=prompt,
#     175         )
#     177         final_response: Response | None = None
#     179         async for chunk in stream:
#
# File ~/.local/lib/python3.13/site-packages/agents/models/openai_responses.py:299, in OpenAIResponsesModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, previous_response_id, conversation_id, stream, prompt)
#     296     else:
#     297         response_format = {"verbosity": model_settings.verbosity}
# --> 299 return await self._client.responses.create(
#     300     previous_response_id=self._non_null_or_not_given(previous_response_id),
#     301     conversation=self._non_null_or_not_given(conversation_id),
#     302     instructions=self._non_null_or_not_given(system_instructions),
#     303     model=self.model,
#     304     input=list_input,
#     305     include=include,
#     306     tools=converted_tools_payload,
#     307     prompt=self._non_null_or_not_given(prompt),
#     308     temperature=self._non_null_or_not_given(model_settings.temperature),
#     309     top_p=self._non_null_or_not_given(model_settings.top_p),
#     310     truncation=self._non_null_or_not_given(model_settings.truncation),
#     311     max_output_tokens=self._non_null_or_not_given(model_settings.max_tokens),
#     312     tool_choice=tool_choice,
#     313     parallel_tool_calls=parallel_tool_calls,
#     314     stream=stream,
#     315     extra_headers={**_HEADERS, **(model_settings.extra_headers or {})},
#     316     extra_query=model_settings.extra_query,
#     317     extra_body=model_settings.extra_body,
#     318     text=response_format,
#     319     store=self._non_null_or_not_given(model_settings.store),
#     320     reasoning=self._non_null_or_not_given(model_settings.reasoning),
#     321     metadata=self._non_null_or_not_given(model_settings.metadata),
#     322     **extra_args,
#     323 )
#
# File ~/.local/lib/python3.13/site-packages/openai/resources/responses/responses.py:2259, in AsyncResponses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    2222 async def create(
#    2223     self,
#    2224     *,
#    (...)   2257     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    2258 ) -> Response | AsyncStream[ResponseStreamEvent]:
# -> 2259     return await self._post(
#    2260         "/responses",
#    2261         body=await async_maybe_transform(
#    2262             {
#    2263                 "background": background,
#    2264                 "conversation": conversation,
#    2265                 "include": include,
#    2266                 "input": input,
#    2267                 "instructions": instructions,
#    2268                 "max_output_tokens": max_output_tokens,
#    2269                 "max_tool_calls": max_tool_calls,
#    2270                 "metadata": metadata,
#    2271                 "model": model,
#    2272                 "parallel_tool_calls": parallel_tool_calls,
#    2273                 "previous_response_id": previous_response_id,
#    2274                 "prompt": prompt,
#    2275                 "prompt_cache_key": prompt_cache_key,
#    2276                 "reasoning": reasoning,
#    2277                 "safety_identifier": safety_identifier,
#    2278                 "service_tier": service_tier,
#    2279                 "store": store,
#    2280                 "stream": stream,
#    2281                 "stream_options": stream_options,
#    2282                 "temperature": temperature,
#    2283                 "text": text,
#    2284                 "tool_choice": tool_choice,
#    2285                 "tools": tools,
#    2286                 "top_logprobs": top_logprobs,
#    2287                 "top_p": top_p,
#    2288                 "truncation": truncation,
#    2289                 "user": user,
#    2290             },
#    2291             response_create_params.ResponseCreateParamsStreaming
#    2292             if stream
#    2293             else response_create_params.ResponseCreateParamsNonStreaming,
#    2294         ),
#    2295         options=make_request_options(
#    2296             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2297         ),
#    2298         cast_to=Response,
#    2299         stream=stream or False,
#    2300         stream_cls=AsyncStream[ResponseStreamEvent],
#    2301     )
#
# File ~/.local/lib/python3.13/site-packages/openai/_base_client.py:1794, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1780 async def post(
#    1781     self,
#    1782     path: str,
#    (...)   1789     stream_cls: type[_AsyncStreamT] | None = None,
#    1790 ) -> ResponseT | _AsyncStreamT:
#    1791     opts = FinalRequestOptions.construct(
#    1792         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1793     )
# -> 1794     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.local/lib/python3.13/site-packages/openai/_base_client.py:1594, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1591             await err.response.aread()
#    1593         log.debug("Re-raising status error")
# -> 1594         raise self._make_status_error_from_response(err.response) from None
#    1596     break
#    1598 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: "sk-proj*********************************************************************************************************************************************************1kQA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %% [markdown]
# _Good Job!_
